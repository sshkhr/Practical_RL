# %%
# launch XVFB if you run on a server
import os
#if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
#    !bash ../xvfb start
#    %env DISPLAY=:1

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
import numpy as np
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
import gym
       
env = gym.make("Acrobot-v1")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n
print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation Space Box(6,)
# Action Space Discrete(3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(env.render('rgb_array'))

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $ \pi_\theta(a|s) $.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape, n_actions, hidden_size = 32):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple: 
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        nn.Module.__init__(self)
        
        #<your network here>
        self.fc1 = nn.Linear(state_shape[0], 128)
        self.fc2 = nn.Linear(128, hidden_size)
        self.fc3 = nn.Linear(hidden_size, n_actions)
        #self.model = None

    def forward(self, states):
        """
        takes agent's observation (Variable), returns log-probabilities (Variable)
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """
        
        # Use your network to compute log_probs for given state
        x = F.relu(self.fc1(states))
        x = F.relu(self.fc2(x))
        x = F.log_softmax(self.fc3(x))
        log_probs = x
        #log_probs = self.model(states)
        return log_probs
    
    def get_log_probs(self, states):
        '''
        Log-probs for training
        '''
        
        return self.forward(states)
    
    def get_probs(self, states):
        '''
        Probs for interaction
        '''
        
        return torch.exp(self.forward(states))
    
    def act(self, obs, sample=True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        probs = self.get_probs(Variable(torch.FloatTensor([obs]))).data.numpy()

        if sample:
            action = int(np.random.choice(n_actions,p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]

agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(Variable(torch.FloatTensor([env.reset()])))
assert isinstance(log_probs, Variable) and log_probs.requires_grad, "qvalues must be a torch variable with grad"
assert len(log_probs.shape) == 2 and log_probs.shape[0] == 1 and log_probs.shape[1] == n_actions
sums = torch.sum(torch.exp(log_probs), dim=1)
assert (0.999<sums).all() and (1.001>sums).all()

# Demo use
print ("sampled:", [agent.act(env.reset()) for _ in range(5)])
print ("greedy:", [agent.act(env.reset(),sample=False) for _ in range(5)])
# Out:
# sampled: [(2, array([0.29350093, 0.35406217, 0.35243687], dtype=float32)), (0, array([0.29319736, 0.3543055 , 0.35249713], dtype=float32)), (0, array([0.2948367 , 0.35302106, 0.3521422 ], dtype=float32)), (1, array([0.29494452, 0.3526591 , 0.35239643], dtype=float32)), (2, array([0.2963443 , 0.35307306, 0.35058263], dtype=float32))]
# greedy: [(1, array([0.29404613, 0.35374615, 0.35220772], dtype=float32)), (1, array([0.29469737, 0.3527181 , 0.3525845 ], dtype=float32)), (1, array([0.29259536, 0.35513118, 0.35227346], dtype=float32)), (1, array([0.29528993, 0.3534651 , 0.35124496], dtype=float32)), (1, array([0.29284042, 0.35451797, 0.3526416 ], dtype=float32))]
# /home/sheshank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = []
    for param in model.parameters():
        params.append(param.data.view(-1))

    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.size())))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].view(param.size()))
        prev_ind += flat_size

# %% [markdown]
# Compute cummulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal
def get_cummulative_returns(r, gamma=1):
    """
    Computes cummulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
#simple demo on rewards [0,0,1,0,0,1]
get_cummulative_returns([0,0,1,0,0,1],gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, done, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if done or total_timesteps==n_timesteps:
                path = {"observations": np.array(obervations),
                        "policy": np.array(action_probs),
                        "actions": np.array(actions),
                        "rewards": np.array(rewards),
                        "cumulative_returns":get_cummulative_returns(rewards),
                       }
                paths.append(path)
                break
    return paths

# %%
paths = rollout(env,agent,max_pathlength=5,n_timesteps=100)
print (paths[-1])
assert (paths[0]['policy'].shape==(5, n_actions))
assert (paths[0]['cumulative_returns'].shape==(5,))
assert (paths[0]['rewards'].shape==(5,))
assert (paths[0]['observations'].shape==(5,)+observation_shape)
assert (paths[0]['actions'].shape==(5,))
print ('It\'s ok')
# Out:
# {'observations': array([[ 0.99796163,  0.06381678,  0.99769082, -0.0679193 , -0.04724528,
#          0.04920874],
#        [ 0.9989482 ,  0.04585306,  0.99894609, -0.04589893, -0.12824578,
#          0.16464926],
#        [ 0.99999835,  0.00181689,  0.99960013,  0.02827701, -0.30078567,
#          0.55722548],
#        [ 0.998498  , -0.05478811,  0.9914204 ,  0.13071188, -0.25097296,
#          0.44457541],
#        [ 0.99433628, -0.10627965,  0.97347577,  0.22879015, -0.25205491,
#          0.52770036]]), 'policy': array([[0.29383337, 0.3539602 , 0.35220647],
#        [0.29541776, 0.3536671 , 0.35091516],
#        [0.2988489 , 0.354088  , 0.34706306],
#        [0.29945514, 0.35394228, 0.34660256],
#        [0.30042702, 0.3544392 , 0.3451338 ]], dtype=float32), 'actions': array([1, 2, 1, 2, 2]), 'rewards': array([-1., -1., -1., -1., -1.]), 'cumulative_returns': array([-5., -4., -3., -2., -1.])}
# It's ok
# /home/sheshank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be
# $$J_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, let's use cummulative returns instead of advantage for now:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Or alternatively, minimize the surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    probs_for_actions = probs_all[torch.arange(0, batch_size, out=torch.LongTensor()), actions]
    old_probs_for_actions = old_probs[torch.arange(0, batch_size, out=torch.LongTensor()), actions]
    
    # Compute surrogate loss, aka importance-sampled policy gradient
    Loss = torch.mean(((probs_for_actions/ old_probs_for_actions) * cummulative_returns),dim = 0, keepdim = True) #<compute surrogate loss>
    Loss = -Loss
    
    assert Loss.shape == torch.Size([1])
    return Loss

# %% [markdown]
# We can ascend these gradients as long as our $pi_\theta(a|s)$ satisfies the constraint
# $$E_{s,\pi_{\Theta_{t}}}\Big[KL(\pi(\Theta_{t}, s) \:||\:\pi(\Theta_{t+1}, s))\Big]< \alpha$$
#
#
# where
#
# $$KL(p||q) = E _p log({p \over q})$$

# %%
def get_kl(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the KL-divergence
    """
    #print(observations.shape)
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    # Compute Kullback-Leibler divergence (see formula above)
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took
    old_log_probs = torch.log(old_probs+1e-10)
    
    #print(log_probs_all.shape)
    #print(old_log_probs.shape)
    
    kl =  torch.mean(torch.sum(old_probs * (old_log_probs - log_probs_all), 1), dim = 0, keepdim = True) #<compute kullback-leibler>
    
    #print(kl.shape)
    
    assert kl.shape == torch.Size([1])
    assert (kl>-0.0001).all() and (kl<10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy 
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """
    
    observations = Variable(torch.FloatTensor(observations))

    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    #print(probs_all.shape)
    
    entropy = torch.sum(-probs_all * log_probs_all) / batch_size
    entropy = entropy.unsqueeze(0)
    #print(entropy.shape)
    
    assert entropy.shape == torch.Size([1])
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x, fullstep, max_kl):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    max_backtracks = 10
    loss, _, = f(x)
    for stepfrac in .5**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        actual_improve = new_loss - loss
        if kl.data.numpy()<=max_kl and actual_improve.data.numpy() < 0:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve Ax=b using conjugate gradients.
#
# In general, CG is an algorithm that solves Ax=b where A is positive-defined. A is Hessian matrix so A is positive-defined. You can find out more about them [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method)

# %%
from numpy.linalg import inv
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros(b.size())
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
#This code validates conjugate gradients
A = np.random.rand(8, 8)
A = np.matmul(np.transpose(A), A)

def f_Ax(x):
    return torch.matmul(torch.FloatTensor(A), x.view((-1, 1))).view(-1)

b = np.random.rand(8)

w = np.matmul(np.matmul(inv(np.matmul(np.transpose(A), A)), np.transpose(A)), b.reshape((-1, 1))).reshape(-1)
print (w)
print (conjugate_gradient(f_Ax, torch.FloatTensor(b)).numpy())
# Out:
# [-1.35473143  0.14159752  0.89792868  0.56655843  0.09597754  0.3434402
#   0.28484079 -0.38971036]
# [-1.3547167   0.14159158  0.8978672   0.5665678   0.09596764  0.3432949
#   0.2849467  -0.3897287 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cummulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """
    
    # Here we prepare the information
    observations = Variable(torch.FloatTensor(observations))
    actions = torch.LongTensor(actions)
    cummulative_returns = Variable(torch.FloatTensor(cummulative_returns))
    old_probs = Variable(torch.FloatTensor(old_probs))
    
    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cummulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([grad.view(-1) for grad in grads]).data

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently
        
        kl = get_kl(agent, observations, actions, cummulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.view(-1) for grad in grads])

        kl_v = (flat_grad_kl * Variable(v)).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([grad.contiguous().view(-1) for grad in grads]).data

        return flat_grad_grad_kl + v * 0.1
    
    # Here we solveolve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)
    
    # Here we get the start point
    prev_params = get_flat_params_from(agent)
    
    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [get_loss(agent, observations, actions, cummulative_returns, old_probs),
                get_kl(agent, observations, actions, cummulative_returns, old_probs)]
    
    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)
    
    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ##### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count
from collections import OrderedDict

max_kl=0.01           #this is hyperparameter of TRPO. It controls how big KL divergence may be between old and new policy every step.
numeptotal = 0        #this is number of episodes that we played.

start_time = time.time()

for i in count(1):

    print ("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print ("Made rollout")
    
    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])
    
    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    #Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = OrderedDict()
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
    i += 1
# Out:
# ********** Iteration 1 ************
# Rollout
# /home/sheshank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Made rollout
# torch.Size([1])
# Total number of episodes:                 101
# Average sum of rewards per episode:       -495.03960396039605
# Std of rewards per episode:               38.862520006161354
# Time elapsed:                             0.23 mins
# KL between old and new distribution:      [0.00755514]
# Entropy:                                  [1.0853854]
# Surrogate loss:                           [249.16348]
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 201
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.46 mins
# KL between old and new distribution:      [0.00639484]
# Entropy:                                  [1.0812769]
# Surrogate loss:                           [250.13094]
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 301
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.68 mins
# KL between old and new distribution:      [0.00546311]
# Entropy:                                  [1.0721369]
# Surrogate loss:                           [250.25572]
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 401
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.91 mins
# KL between old and new distribution:      [0.00996829]
# Entropy:                                  [1.0757347]
# Surrogate loss:                           [250.10284]
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 501
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             1.14 mins
# KL between old and new distribution:      [0.00999201]
# Entropy:                                  [1.0384768]
# Surrogate loss:                           [250.06181]
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 601
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             1.36 mins
# KL between old and new distribution:      [0.00998171]
# Entropy:                                  [1.0317473]
# Surrogate loss:                           [249.93571]
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 701
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             1.59 mins
# KL between old and new distribution:      [0.00996136]
# Entropy:                                  [1.0497257]
# Surrogate loss:                           [249.88177]
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 801
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             1.82 mins
# KL between old and new distribution:      [0.00998612]
# Entropy:                                  [1.0717288]
# Surrogate loss:                           [250.06534]
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 901
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             2.04 mins
# KL between old and new distribution:      [0.0099909]
# Entropy:                                  [1.0562271]
# Surrogate loss:                           [249.87051]
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1001
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             2.27 mins
# KL between old and new distribution:      [0.00999651]
# Entropy:                                  [1.0603826]
# Surrogate loss:                           [249.97426]
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1102
# Average sum of rewards per episode:       -495.03960396039605
# Std of rewards per episode:               48.32110433957018
# Time elapsed:                             2.51 mins
# KL between old and new distribution:      [0.00998302]
# Entropy:                                  [1.0154703]
# Surrogate loss:                           [249.83304]
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1207
# Average sum of rewards per episode:       -475.9142857142857
# Std of rewards per episode:               45.581975193984675
# Time elapsed:                             2.79 mins
# KL between old and new distribution:      [0.00999914]
# Entropy:                                  [0.92220134]
# Surrogate loss:                           [239.88878]
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1318
# Average sum of rewards per episode:       -450.036036036036
# Std of rewards per episode:               76.89315483164066
# Time elapsed:                             3.04 mins
# KL between old and new distribution:      [0.00996615]
# Entropy:                                  [0.9062922]
# Surrogate loss:                           [230.94041]
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1464
# Average sum of rewards per episode:       -341.5342465753425
# Std of rewards per episode:               77.5234974881069
# Time elapsed:                             3.29 mins
# KL between old and new distribution:      [0.00998046]
# Entropy:                                  [0.79487884]
# Surrogate loss:                           [179.15115]
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1654
# Average sum of rewards per episode:       -262.1684210526316
# Std of rewards per episode:               58.21351852973834
# Time elapsed:                             3.53 mins
# KL between old and new distribution:      [0.00999194]
# Entropy:                                  [0.7054325]
# Surrogate loss:                           [137.0184]
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 1869
# Average sum of rewards per episode:       -231.58139534883722
# Std of rewards per episode:               63.333900161611
# Time elapsed:                             3.76 mins
# KL between old and new distribution:      [0.00997942]
# Entropy:                                  [0.67484796]
# Surrogate loss:                           [123.86361]
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 2119
# Average sum of rewards per episode:       -199.016
# Std of rewards per episode:               57.77113244519273
# Time elapsed:                             3.99 mins
# KL between old and new distribution:      [0.00998969]
# Entropy:                                  [0.6196222]
# Surrogate loss:                           [107.49225]
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 2390
# Average sum of rewards per episode:       -183.50922509225092
# Std of rewards per episode:               43.2176217534795
# Time elapsed:                             4.23 mins
# KL between old and new distribution:      [0.00999548]
# Entropy:                                  [0.62558174]
# Surrogate loss:                           [96.44014]
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 2693
# Average sum of rewards per episode:       -164.02310231023102
# Std of rewards per episode:               37.039308273405574
# Time elapsed:                             4.47 mins
# KL between old and new distribution:      [0.00999159]
# Entropy:                                  [0.57954276]
# Surrogate loss:                           [85.93124]
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 3013
# Average sum of rewards per episode:       -155.25625
# Std of rewards per episode:               39.50003906248069
# Time elapsed:                             4.70 mins
# KL between old and new distribution:      [0.0099787]
# Entropy:                                  [0.5712321]
# Surrogate loss:                           [82.40174]
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 3347
# Average sum of rewards per episode:       -148.70658682634732
# Std of rewards per episode:               42.04735160474438
# Time elapsed:                             4.94 mins
# KL between old and new distribution:      [0.00998664]
# Entropy:                                  [0.56785303]
# Surrogate loss:                           [79.8688]
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 3707
# Average sum of rewards per episode:       -137.8972222222222
# Std of rewards per episode:               38.2847952565964
# Time elapsed:                             5.17 mins
# KL between old and new distribution:      [0.00997556]
# Entropy:                                  [0.608255]
# Surrogate loss:                           [73.86848]
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 4082
# Average sum of rewards per episode:       -132.33866666666665
# Std of rewards per episode:               35.22135675347495
# Time elapsed:                             5.40 mins
# KL between old and new distribution:      [0.00997598]
# Entropy:                                  [0.5948947]
# Surrogate loss:                           [70.53356]
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 4474
# Average sum of rewards per episode:       -126.56122448979592
# Std of rewards per episode:               43.695973364791215
# Time elapsed:                             5.64 mins
# KL between old and new distribution:      [0.00999814]
# Entropy:                                  [0.56467515]
# Surrogate loss:                           [70.51031]
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 4867
# Average sum of rewards per episode:       -126.23155216284987
# Std of rewards per episode:               40.15782885318225
# Time elapsed:                             5.87 mins
# KL between old and new distribution:      [0.00998744]
# Entropy:                                  [0.5121952]
# Surrogate loss:                           [69.23962]
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 5262
# Average sum of rewards per episode:       -125.58481012658228
# Std of rewards per episode:               28.111978115592347
# Time elapsed:                             6.10 mins
# KL between old and new distribution:      [0.00998002]
# Entropy:                                  [0.52423674]
# Surrogate loss:                           [65.617226]
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 5669
# Average sum of rewards per episode:       -121.85503685503686
# Std of rewards per episode:               37.89784689074586
# Time elapsed:                             6.33 mins
# KL between old and new distribution:      [0.00998705]
# Entropy:                                  [0.5352374]
# Surrogate loss:                           [66.47363]
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 6094
# Average sum of rewards per episode:       -116.64941176470589
# Std of rewards per episode:               29.499940672041685
# Time elapsed:                             6.57 mins
# KL between old and new distribution:      [0.00999538]
# Entropy:                                  [0.5670564]
# Surrogate loss:                           [61.784294]
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 6516
# Average sum of rewards per episode:       -117.48578199052133
# Std of rewards per episode:               29.847218177232136
# Time elapsed:                             6.80 mins
# KL between old and new distribution:      [0.009991]
# Entropy:                                  [0.5844427]
# Surrogate loss:                           [62.25136]
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 6944
# Average sum of rewards per episode:       -115.82476635514018
# Std of rewards per episode:               25.41082342969855
# Time elapsed:                             7.02 mins
# KL between old and new distribution:      [0.00997913]
# Entropy:                                  [0.5804274]
# Surrogate loss:                           [60.467403]
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 7377
# Average sum of rewards per episode:       -114.47575057736721
# Std of rewards per episode:               31.573002593939503
# Time elapsed:                             7.25 mins
# KL between old and new distribution:      [0.00999236]
# Entropy:                                  [0.551998]
# Surrogate loss:                           [61.351715]
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 7827
# Average sum of rewards per episode:       -110.12222222222222
# Std of rewards per episode:               43.622019867080326
# Time elapsed:                             7.48 mins
# KL between old and new distribution:      [0.00999215]
# Entropy:                                  [0.534698]
# Surrogate loss:                           [63.27581]
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 8268
# Average sum of rewards per episode:       -112.3922902494331
# Std of rewards per episode:               50.07950897793737
# Time elapsed:                             7.71 mins
# KL between old and new distribution:      [0.00997516]
# Entropy:                                  [0.5218851]
# Surrogate loss:                           [66.884895]
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 8747
# Average sum of rewards per episode:       -103.38622129436325
# Std of rewards per episode:               25.442208000374638
# Time elapsed:                             7.94 mins
# KL between old and new distribution:      [0.0099905]
# Entropy:                                  [0.49717122]
# Surrogate loss:                           [54.60261]
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 9223
# Average sum of rewards per episode:       -104.05042016806723
# Std of rewards per episode:               43.202639341155376
# Time elapsed:                             8.16 mins
# KL between old and new distribution:      [0.00998812]
# Entropy:                                  [0.45779136]
# Surrogate loss:                           [60.691216]
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 9699
# Average sum of rewards per episode:       -104.04621848739495
# Std of rewards per episode:               42.33353417743743
# Time elapsed:                             8.39 mins
# KL between old and new distribution:      [0.00999969]
# Entropy:                                  [0.44914192]
# Surrogate loss:                           [60.313416]
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 10194
# Average sum of rewards per episode:       -100.01818181818182
# Std of rewards per episode:               39.011234754853064
# Time elapsed:                             8.63 mins
# KL between old and new distribution:      [0.00997416]
# Entropy:                                  [0.45345324]
# Surrogate loss:                           [57.308327]
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 10686
# Average sum of rewards per episode:       -100.630081300813
# Std of rewards per episode:               36.45987533919291
# Time elapsed:                             8.90 mins
# KL between old and new distribution:      [0.00998997]
# Entropy:                                  [0.46951953]
# Surrogate loss:                           [56.543514]
#
# ********** Iteration 39 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 11194
# Average sum of rewards per episode:       -97.42913385826772
# Std of rewards per episode:               33.02464031225375
# Time elapsed:                             9.13 mins
# KL between old and new distribution:      [0.00998119]
# Entropy:                                  [0.45221892]
# Surrogate loss:                           [54.06899]
#
# ********** Iteration 40 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 11704
# Average sum of rewards per episode:       -97.04313725490196
# Std of rewards per episode:               34.73544415080524
# Time elapsed:                             9.36 mins
# KL between old and new distribution:      [0.00998743]
# Entropy:                                  [0.41115505]
# Surrogate loss:                           [54.423145]
#
# ********** Iteration 41 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 12231
# Average sum of rewards per episode:       -93.8785578747628
# Std of rewards per episode:               26.681913925871196
# Time elapsed:                             9.61 mins
# KL between old and new distribution:      [0.00998681]
# Entropy:                                  [0.36732563]
# Surrogate loss:                           [50.545444]
#
# ********** Iteration 42 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 12757
# Average sum of rewards per episode:       -94.06083650190114
# Std of rewards per episode:               35.99714958170284
# Time elapsed:                             9.84 mins
# KL between old and new distribution:      [0.00997885]
# Entropy:                                  [0.3504656]
# Surrogate loss:                           [53.6718]
#
# ********** Iteration 43 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 13283
# Average sum of rewards per episode:       -94.06463878326996
# Std of rewards per episode:               40.7697280683924
# Time elapsed:                             10.09 mins
# KL between old and new distribution:      [0.00998002]
# Entropy:                                  [0.30213782]
# Surrogate loss:                           [55.46065]
#
# ********** Iteration 44 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 13836
# Average sum of rewards per episode:       -89.41952983725136
# Std of rewards per episode:               30.08441015406195
# Time elapsed:                             10.32 mins
# KL between old and new distribution:      [0.0099925]
# Entropy:                                  [0.26076806]
# Surrogate loss:                           [49.566154]
#
# ********** Iteration 45 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 14391
# Average sum of rewards per episode:       -89.09189189189189
# Std of rewards per episode:               31.78900919232548
# Time elapsed:                             10.56 mins
# KL between old and new distribution:      [0.00999039]
# Entropy:                                  [0.25561777]
# Surrogate loss:                           [49.98197]
#
# ********** Iteration 46 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 14948
# Average sum of rewards per episode:       -88.77199281867145
# Std of rewards per episode:               38.94220832242156
# Time elapsed:                             10.79 mins
# KL between old and new distribution:      [0.00998792]
# Entropy:                                  [0.20627752]
# Surrogate loss:                           [52.656624]
#
# ********** Iteration 47 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 15508
# Average sum of rewards per episode:       -88.2875
# Std of rewards per episode:               29.23160937422267
# Time elapsed:                             11.02 mins
# KL between old and new distribution:      [0.00999575]
# Entropy:                                  [0.17951608]
# Surrogate loss:                           [48.76874]
#
# ********** Iteration 48 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 16079
# Average sum of rewards per episode:       -86.56742556917688
# Std of rewards per episode:               27.04637497894872
# Time elapsed:                             11.25 mins
# KL between old and new distribution:      [0.00997942]
# Entropy:                                  [0.18215066]
# Surrogate loss:                           [47.319633]
#
# ********** Iteration 49 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 16654
# Average sum of rewards per episode:       -85.96173913043478
# Std of rewards per episode:               33.160719514427846
# Time elapsed:                             11.48 mins
# KL between old and new distribution:      [0.00999615]
# Entropy:                                  [0.17173068]
# Surrogate loss:                           [49.190594]
#
# ********** Iteration 50 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 17235
# Average sum of rewards per episode:       -85.06024096385542
# Std of rewards per episode:               25.02112331591308
# Time elapsed:                             11.71 mins
# KL between old and new distribution:      [0.00999657]
# Entropy:                                  [0.16954818]
# Surrogate loss:                           [45.971054]
#
# ********** Iteration 51 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 17797
# Average sum of rewards per episode:       -87.97153024911032
# Std of rewards per episode:               30.450635171632243
# Time elapsed:                             11.94 mins
# KL between old and new distribution:      [0.00999425]
# Entropy:                                  [0.19451821]
# Surrogate loss:                           [48.988457]
#
# ********** Iteration 52 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 18383
# Average sum of rewards per episode:       -84.3259385665529
# Std of rewards per episode:               23.842871078211168
# Time elapsed:                             12.17 mins
# KL between old and new distribution:      [0.00999798]
# Entropy:                                  [0.18589851]
# Surrogate loss:                           [45.355465]
#
# ********** Iteration 53 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 18953
# Average sum of rewards per episode:       -86.72105263157894
# Std of rewards per episode:               29.88517931603583
# Time elapsed:                             12.40 mins
# KL between old and new distribution:      [0.00997341]
# Entropy:                                  [0.16519552]
# Surrogate loss:                           [48.283314]
#
# ********** Iteration 54 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 19528
# Average sum of rewards per episode:       -85.95826086956522
# Std of rewards per episode:               27.27135774942576
# Time elapsed:                             12.63 mins
# KL between old and new distribution:      [0.00998784]
# Entropy:                                  [0.16341703]
# Surrogate loss:                           [47.10069]
#
# ********** Iteration 55 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 20099
# Average sum of rewards per episode:       -86.56742556917688
# Std of rewards per episode:               26.960766530297366
# Time elapsed:                             12.86 mins
# KL between old and new distribution:      [0.00997663]
# Entropy:                                  [0.17421293]
# Surrogate loss:                           [47.252045]
#
# ********** Iteration 56 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 20670
# Average sum of rewards per episode:       -86.56742556917688
# Std of rewards per episode:               23.563312415092557
# Time elapsed:                             13.09 mins
# KL between old and new distribution:      [0.00998957]
# Entropy:                                  [0.17262024]
# Surrogate loss:                           [46.29842]
#
# ********** Iteration 57 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 21238
# Average sum of rewards per episode:       -87.03169014084507
# Std of rewards per episode:               33.110555037478655
# Time elapsed:                             13.32 mins
# KL between old and new distribution:      [0.00999883]
# Entropy:                                  [0.1618459]
# Surrogate loss:                           [49.499546]
#
# ********** Iteration 58 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 21832
# Average sum of rewards per episode:       -83.17676767676768
# Std of rewards per episode:               23.162085856025968
# Time elapsed:                             13.55 mins
# KL between old and new distribution:      [0.00999151]
# Entropy:                                  [0.17679936]
# Surrogate loss:                           [44.59666]
#
# ********** Iteration 59 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 22417
# Average sum of rewards per episode:       -84.47179487179487
# Std of rewards per episode:               23.401065963571547
# Time elapsed:                             13.78 mins
# KL between old and new distribution:      [0.00997748]
# Entropy:                                  [0.21331066]
# Surrogate loss:                           [45.249805]
#
# ********** Iteration 60 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 22985
# Average sum of rewards per episode:       -87.03169014084507
# Std of rewards per episode:               31.303192182354117
# Time elapsed:                             14.00 mins
# KL between old and new distribution:      [0.00998968]
# Entropy:                                  [0.20919791]
# Surrogate loss:                           [48.892246]
#
# ********** Iteration 61 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 23567
# Average sum of rewards per episode:       -84.91408934707904
# Std of rewards per episode:               30.97448524508846
# Time elapsed:                             14.23 mins
# KL between old and new distribution:      [0.009973]
# Entropy:                                  [0.2158279]
# Surrogate loss:                           [47.82158]
#
# ********** Iteration 62 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 24153
# Average sum of rewards per episode:       -84.3259385665529
# Std of rewards per episode:               22.062846386447823
# Time elapsed:                             14.47 mins
# KL between old and new distribution:      [0.00998034]
# Entropy:                                  [0.176644]
# Surrogate loss:                           [44.84889]
#
# ********** Iteration 63 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 24721
# Average sum of rewards per episode:       -87.03169014084507
# Std of rewards per episode:               36.759195208201874
# Time elapsed:                             14.70 mins
# KL between old and new distribution:      [0.00999283]
# Entropy:                                  [0.18358167]
# Surrogate loss:                           [51.04762]
#
# ********** Iteration 64 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 25299
# Average sum of rewards per episode:       -85.51038062283737
# Std of rewards per episode:               35.56952443754707
# Time elapsed:                             14.93 mins
# KL between old and new distribution:      [0.00998502]
# Entropy:                                  [0.16693592]
# Surrogate loss:                           [49.897717]
#
# ********** Iteration 65 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 25880
# Average sum of rewards per episode:       -85.06368330464716
# Std of rewards per episode:               35.497367086618524
# Time elapsed:                             15.15 mins
# KL between old and new distribution:      [0.00998203]
# Entropy:                                  [0.16285034]
# Surrogate loss:                           [49.64901]
#
# ********** Iteration 66 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 26463
# Average sum of rewards per episode:       -84.76672384219555
# Std of rewards per episode:               30.45037225668008
# Time elapsed:                             15.38 mins
# KL between old and new distribution:      [0.00999643]
# Entropy:                                  [0.15340003]
# Surrogate loss:                           [47.641685]
#
# ********** Iteration 67 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 27045
# Average sum of rewards per episode:       -84.91580756013745
# Std of rewards per episode:               34.03573204682054
# Time elapsed:                             15.60 mins
# KL between old and new distribution:      [0.00998521]
# Entropy:                                  [0.13813311]
# Surrogate loss:                           [49.075443]
#
# ********** Iteration 68 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 27637
# Average sum of rewards per episode:       -83.46114864864865
# Std of rewards per episode:               22.955491100248306
# Time elapsed:                             15.84 mins
# KL between old and new distribution:      [0.00997675]
# Entropy:                                  [0.1396691]
# Surrogate loss:                           [44.70664]
#
# ********** Iteration 69 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 28239
# Average sum of rewards per episode:       -82.05813953488372
# Std of rewards per episode:               20.85478048227597
# Time elapsed:                             16.07 mins
# KL between old and new distribution:      [0.00997889]
# Entropy:                                  [0.12698774]
# Surrogate loss:                           [43.525757]
#
# ********** Iteration 70 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 28823
# Average sum of rewards per episode:       -84.61986301369863
# Std of rewards per episode:               27.59105751463244
# Time elapsed:                             16.30 mins
# KL between old and new distribution:      [0.00997406]
# Entropy:                                  [0.10732596]
# Surrogate loss:                           [46.64407]
#
# ********** Iteration 71 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 29401
# Average sum of rewards per episode:       -85.50692041522491
# Std of rewards per episode:               24.193799154034842
# Time elapsed:                             16.52 mins
# KL between old and new distribution:      [0.0099862]
# Entropy:                                  [0.1230485]
# Surrogate loss:                           [45.987495]
#
# ********** Iteration 72 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 30009
# Average sum of rewards per episode:       -81.23848684210526
# Std of rewards per episode:               19.196457467181297
# Time elapsed:                             16.75 mins
# KL between old and new distribution:      [0.00999408]
# Entropy:                                  [0.11223488]
# Surrogate loss:                           [42.74584]
#
# ********** Iteration 73 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 30614
# Average sum of rewards per episode:       -81.64628099173554
# Std of rewards per episode:               23.10294261005203
# Time elapsed:                             16.98 mins
# KL between old and new distribution:      [0.00997791]
# Entropy:                                  [0.11033855]
# Surrogate loss:                           [43.87742]
#
# ********** Iteration 74 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 31174
# Average sum of rewards per episode:       -88.29107142857143
# Std of rewards per episode:               37.154012361605396
# Time elapsed:                             17.20 mins
# KL between old and new distribution:      [0.00999894]
# Entropy:                                  [0.13488601]
# Surrogate loss:                           [51.69569]
#
# ********** Iteration 75 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 31769
# Average sum of rewards per episode:       -83.03361344537815
# Std of rewards per episode:               21.503696290868305
# Time elapsed:                             17.46 mins
# KL between old and new distribution:      [0.00996613]
# Entropy:                                  [0.1432284]
# Surrogate loss:                           [44.038425]
#
# ********** Iteration 76 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 32363
# Average sum of rewards per episode:       -83.17676767676768
# Std of rewards per episode:               27.80398075422012
# Time elapsed:                             17.70 mins
# KL between old and new distribution:      [0.00996715]
# Entropy:                                  [0.15508588]
# Surrogate loss:                           [45.880585]
#
# ********** Iteration 77 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 32960
# Average sum of rewards per episode:       -82.75544388609715
# Std of rewards per episode:               27.35902788317803
# Time elapsed:                             17.94 mins
# KL between old and new distribution:      [0.00998188]
# Entropy:                                  [0.16252036]
# Surrogate loss:                           [45.663406]
#
# ********** Iteration 78 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 33554
# Average sum of rewards per episode:       -83.18013468013469
# Std of rewards per episode:               32.562080712364825
# Time elapsed:                             18.17 mins
# KL between old and new distribution:      [0.0099792]
# Entropy:                                  [0.14867395]
# Surrogate loss:                           [47.727116]
#
# ********** Iteration 79 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 34156
# Average sum of rewards per episode:       -82.05980066445183
# Std of rewards per episode:               28.85989317110007
# Time elapsed:                             18.40 mins
# KL between old and new distribution:      [0.00999379]
# Entropy:                                  [0.13261835]
# Surrogate loss:                           [45.89438]
#
# ********** Iteration 80 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 34742
# Average sum of rewards per episode:       -84.3259385665529
# Std of rewards per episode:               25.151986660954098
# Time elapsed:                             18.64 mins
# KL between old and new distribution:      [0.00999436]
# Entropy:                                  [0.12941676]
# Surrogate loss:                           [45.66734]
#
# ********** Iteration 81 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 35336
# Average sum of rewards per episode:       -83.17845117845118
# Std of rewards per episode:               27.949120565092823
# Time elapsed:                             18.86 mins
# KL between old and new distribution:      [0.00997418]
# Entropy:                                  [0.12503555]
# Surrogate loss:                           [46.090195]
#
# ********** Iteration 82 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 35935
# Average sum of rewards per episode:       -82.47746243739566
# Std of rewards per episode:               32.586841618193944
# Time elapsed:                             19.10 mins
# KL between old and new distribution:      [0.00999568]
# Entropy:                                  [0.12770393]
# Surrogate loss:                           [47.3996]
#
# ********** Iteration 83 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 36545
# Average sum of rewards per episode:       -80.96885245901639
# Std of rewards per episode:               19.9503649745456
# Time elapsed:                             19.33 mins
# KL between old and new distribution:      [0.00998549]
# Entropy:                                  [0.1173353]
# Surrogate loss:                           [42.78655]
#
# ********** Iteration 84 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 37143
# Average sum of rewards per episode:       -82.61371237458194
# Std of rewards per episode:               19.51012804293503
# Time elapsed:                             19.56 mins
# KL between old and new distribution:      [0.00998518]
# Entropy:                                  [0.09902477]
# Surrogate loss:                           [43.458485]
#
# ********** Iteration 85 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 37732
# Average sum of rewards per episode:       -83.89134125636673
# Std of rewards per episode:               20.23935909990446
# Time elapsed:                             19.78 mins
# KL between old and new distribution:      [0.00996738]
# Entropy:                                  [0.1009722]
# Surrogate loss:                           [44.16249]
#
# ********** Iteration 86 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 38336
# Average sum of rewards per episode:       -81.78476821192054
# Std of rewards per episode:               28.04472598207817
# Time elapsed:                             20.01 mins
# KL between old and new distribution:      [0.00998685]
# Entropy:                                  [0.08654816]
# Surrogate loss:                           [45.485004]
#
# ********** Iteration 87 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 38933
# Average sum of rewards per episode:       -82.7537688442211
# Std of rewards per episode:               23.73460195615083
# Time elapsed:                             20.23 mins
# KL between old and new distribution:      [0.00997224]
# Entropy:                                  [0.08252676]
# Surrogate loss:                           [44.572845]
#
# ********** Iteration 88 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 39528
# Average sum of rewards per episode:       -83.03697478991597
# Std of rewards per episode:               31.824761422320197
# Time elapsed:                             20.46 mins
# KL between old and new distribution:      [0.00998935]
# Entropy:                                  [0.08829352]
# Surrogate loss:                           [47.417744]
#
# ********** Iteration 89 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 40136
# Average sum of rewards per episode:       -81.23848684210526
# Std of rewards per episode:               22.436548667997176
# Time elapsed:                             20.68 mins
# KL between old and new distribution:      [0.00999424]
# Entropy:                                  [0.07704904]
# Surrogate loss:                           [43.58179]
#
# ********** Iteration 90 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 40745
# Average sum of rewards per episode:       -81.10344827586206
# Std of rewards per episode:               21.177197621759014
# Time elapsed:                             20.90 mins
# KL between old and new distribution:      [0.00999459]
# Entropy:                                  [0.08021124]
# Surrogate loss:                           [43.10072]
#
# ********** Iteration 91 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 41333
# Average sum of rewards per episode:       -84.0374149659864
# Std of rewards per episode:               28.12796248557133
# Time elapsed:                             21.13 mins
# KL between old and new distribution:      [0.00998269]
# Entropy:                                  [0.08571433]
# Surrogate loss:                           [46.443016]
#
# ********** Iteration 92 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 41946
# Average sum of rewards per episode:       -80.56769983686786
# Std of rewards per episode:               20.29868487357465
# Time elapsed:                             21.36 mins
# KL between old and new distribution:      [0.00998478]
# Entropy:                                  [0.07174756]
# Surrogate loss:                           [42.710667]
#
# ********** Iteration 93 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 42560
# Average sum of rewards per episode:       -80.43485342019544
# Std of rewards per episode:               20.446278785728374
# Time elapsed:                             21.58 mins
# KL between old and new distribution:      [0.00999184]
# Entropy:                                  [0.0638621]
# Surrogate loss:                           [42.6696]
#
# ********** Iteration 94 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 43194
# Average sum of rewards per episode:       -77.86593059936908
# Std of rewards per episode:               16.219978533563257
# Time elapsed:                             21.81 mins
# KL between old and new distribution:      [0.00998]
# Entropy:                                  [0.06723052]
# Surrogate loss:                           [40.5278]
#
# ********** Iteration 95 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 43798
# Average sum of rewards per episode:       -81.78476821192054
# Std of rewards per episode:               26.992457245035737
# Time elapsed:                             22.03 mins
# KL between old and new distribution:      [0.00997686]
# Entropy:                                  [0.07597721]
# Surrogate loss:                           [45.09752]
#
# ********** Iteration 96 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 44415
# Average sum of rewards per episode:       -80.03889789303079
# Std of rewards per episode:               26.171392031374914
# Time elapsed:                             22.25 mins
# KL between old and new distribution:      [0.00999498]
# Entropy:                                  [0.07091961]
# Surrogate loss:                           [44.057396]
#
# ********** Iteration 97 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 45045
# Average sum of rewards per episode:       -78.36825396825397
# Std of rewards per episode:               25.495488710170292
# Time elapsed:                             22.47 mins
# KL between old and new distribution:      [0.00998091]
# Entropy:                                  [0.08262935]
# Surrogate loss:                           [43.123554]
#
# ********** Iteration 98 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 45662
# Average sum of rewards per episode:       -80.04051863857374
# Std of rewards per episode:               27.343898694978094
# Time elapsed:                             22.70 mins
# KL between old and new distribution:      [0.00999147]
# Entropy:                                  [0.08331491]
# Surrogate loss:                           [44.539635]
#
# ********** Iteration 99 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 46299
# Average sum of rewards per episode:       -77.49450549450549
# Std of rewards per episode:               16.192679643870804
# Time elapsed:                             22.92 mins
# KL between old and new distribution:      [0.00998342]
# Entropy:                                  [0.08287773]
# Surrogate loss:                           [40.33634]
#
# ********** Iteration 100 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 46938
# Average sum of rewards per episode:       -77.24882629107981
# Std of rewards per episode:               18.145190674991458
# Time elapsed:                             23.14 mins
# KL between old and new distribution:      [0.00998958]
# Entropy:                                  [0.07346983]
# Surrogate loss:                           [40.634956]
#
# ********** Iteration 101 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 47581
# Average sum of rewards per episode:       -76.76205287713842
# Std of rewards per episode:               17.89039526542206
# Time elapsed:                             23.37 mins
# KL between old and new distribution:      [0.00999361]
# Entropy:                                  [0.07390162]
# Surrogate loss:                           [40.294834]
#
# ********** Iteration 102 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 48211
# Average sum of rewards per episode:       -78.36666666666666
# Std of rewards per episode:               24.751536748827768
# Time elapsed:                             23.62 mins
# KL between old and new distribution:      [0.00998273]
# Entropy:                                  [0.08193579]
# Surrogate loss:                           [42.858265]
#
# ********** Iteration 103 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 48846
# Average sum of rewards per episode:       -77.74173228346457
# Std of rewards per episode:               21.83278052975872
# Time elapsed:                             23.86 mins
# KL between old and new distribution:      [0.00997445]
# Entropy:                                  [0.08304361]
# Surrogate loss:                           [41.782803]
#
# ********** Iteration 104 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 49466
# Average sum of rewards per episode:       -79.64677419354838
# Std of rewards per episode:               17.720939115706027
# Time elapsed:                             24.08 mins
# KL between old and new distribution:      [0.00999848]
# Entropy:                                  [0.090106]
# Surrogate loss:                           [41.654358]
#
# ********** Iteration 105 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 50103
# Average sum of rewards per episode:       -77.49450549450549
# Std of rewards per episode:               18.33686316298764
# ...
# Time elapsed:                             31.45 mins
# KL between old and new distribution:      [0.0099704]
# Entropy:                                  [0.05557667]
# Surrogate loss:                           [38.09315]
#
# ********** Iteration 137 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 70976
# Average sum of rewards per episode:       -74.53021148036254
# Std of rewards per episode:               14.652618821352588
# Time elapsed:                             31.68 mins
# KL between old and new distribution:      [0.00999917]
# Entropy:                                  [0.05556099]
# Surrogate loss:                           [38.590866]
#
# ********** Iteration 138 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 71633
# Average sum of rewards per episode:       -75.10502283105023
# Std of rewards per episode:               22.21123693783079
# Time elapsed:                             31.91 mins
# KL between old and new distribution:      [0.00999458]
# Entropy:                                  [0.05282355]
# Surrogate loss:                           [40.66961]
#
# ********** Iteration 139 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 72278
# Average sum of rewards per episode:       -76.52248062015504
# Std of rewards per episode:               24.942753807267046
# Time elapsed:                             32.14 mins
# KL between old and new distribution:      [0.00998896]
# Entropy:                                  [0.0545063]
# Surrogate loss:                           [41.91973]
#
# ********** Iteration 140 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 72938
# Average sum of rewards per episode:       -74.75909090909092
# Std of rewards per episode:               20.795056793679155
# Time elapsed:                             32.37 mins
# KL between old and new distribution:      [0.00998831]
# Entropy:                                  [0.0479013]
# Surrogate loss:                           [40.12617]
#
# ********** Iteration 141 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 73601
# Average sum of rewards per episode:       -74.41628959276018
# Std of rewards per episode:               13.208566172009713
# Time elapsed:                             32.59 mins
# KL between old and new distribution:      [0.00998063]
# Entropy:                                  [0.04111299]
# Surrogate loss:                           [38.290432]
#
# ********** Iteration 142 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 74257
# Average sum of rewards per episode:       -75.22256097560975
# Std of rewards per episode:               22.450606559841955
# Time elapsed:                             32.82 mins
# KL between old and new distribution:      [0.00911882]
# Entropy:                                  [0.03793305]
# Surrogate loss:                           [40.67277]
#
# ********** Iteration 143 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 74922
# Average sum of rewards per episode:       -74.18947368421053
# Std of rewards per episode:               15.421307704015865
# Time elapsed:                             33.04 mins
# KL between old and new distribution:      [0.00950565]
# Entropy:                                  [0.03796575]
# Surrogate loss:                           [38.599186]
#
# ********** Iteration 144 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 75581
# Average sum of rewards per episode:       -74.87405159332322
# Std of rewards per episode:               12.885779665021703
# Time elapsed:                             33.27 mins
# KL between old and new distribution:      [0.00998783]
# Entropy:                                  [0.03895544]
# Surrogate loss:                           [38.414444]
#
# ********** Iteration 145 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 76257
# Average sum of rewards per episode:       -72.96597633136095
# Std of rewards per episode:               13.289016322362157
# Time elapsed:                             33.50 mins
# KL between old and new distribution:      [0.00998403]
# Entropy:                                  [0.04064349]
# Surrogate loss:                           [37.550903]
#
# ********** Iteration 146 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 76922
# Average sum of rewards per episode:       -74.18947368421053
# Std of rewards per episode:               16.409704002122567
# Time elapsed:                             33.72 mins
# KL between old and new distribution:      [0.00571797]
# Entropy:                                  [0.03985141]
# Surrogate loss:                           [38.83603]
#
# ********** Iteration 147 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 77588
# Average sum of rewards per episode:       -74.07657657657657
# Std of rewards per episode:               15.66901911582036
# Time elapsed:                             33.95 mins
# KL between old and new distribution:      [0.0099999]
# Entropy:                                  [0.04013991]
# Surrogate loss:                           [38.5834]
#
# ********** Iteration 148 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 78266
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               15.09595032928604
# Time elapsed:                             34.18 mins
# KL between old and new distribution:      [0.00998311]
# Entropy:                                  [0.04099797]
# Surrogate loss:                           [37.81425]
#
# ********** Iteration 149 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 78929
# Average sum of rewards per episode:       -74.41779788838612
# Std of rewards per episode:               21.89021248622732
# Time elapsed:                             34.41 mins
# KL between old and new distribution:      [0.00998911]
# Entropy:                                  [0.03823931]
# Surrogate loss:                           [40.24343]
#
# ********** Iteration 150 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 79593
# Average sum of rewards per episode:       -74.30421686746988
# Std of rewards per episode:               22.001730086435064
# Time elapsed:                             34.63 mins
# KL between old and new distribution:      [0.00999149]
# Entropy:                                  [0.03440858]
# Surrogate loss:                           [40.182095]
#
# ********** Iteration 151 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 80264
# Average sum of rewards per episode:       -73.5171385991058
# Std of rewards per episode:               17.507569276639156
# Time elapsed:                             34.86 mins
# KL between old and new distribution:      [0.00999581]
# Entropy:                                  [0.03503895]
# Surrogate loss:                           [38.69724]
#
# ********** Iteration 152 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 80925
# Average sum of rewards per episode:       -74.64750378214826
# Std of rewards per episode:               26.5052978571279
# Time elapsed:                             35.09 mins
# KL between old and new distribution:      [0.00998747]
# Entropy:                                  [0.04224624]
# Surrogate loss:                           [41.85931]
#
# ********** Iteration 153 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 81577
# Average sum of rewards per episode:       -75.69018404907976
# Std of rewards per episode:               23.527018053585397
# Time elapsed:                             35.31 mins
# KL between old and new distribution:      [0.00998285]
# Entropy:                                  [0.03833671]
# Surrogate loss:                           [41.16013]
#
# ********** Iteration 154 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 82234
# Average sum of rewards per episode:       -75.10502283105023
# Std of rewards per episode:               18.894151746108058
# Time elapsed:                             35.54 mins
# KL between old and new distribution:      [0.0099923]
# Entropy:                                  [0.03763388]
# Surrogate loss:                           [39.801655]
#
# ********** Iteration 155 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 82907
# Average sum of rewards per episode:       -73.29569093610698
# Std of rewards per episode:               15.189548173180498
# Time elapsed:                             35.77 mins
# KL between old and new distribution:      [0.00999486]
# Entropy:                                  [0.03659132]
# Surrogate loss:                           [38.070873]
#
# ********** Iteration 156 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 83582
# Average sum of rewards per episode:       -73.07555555555555
# Std of rewards per episode:               15.612679873727833
# Time elapsed:                             36.00 mins
# KL between old and new distribution:      [0.00998251]
# Entropy:                                  [0.03738347]
# Surrogate loss:                           [38.06445]
#
# ********** Iteration 157 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 84264
# Average sum of rewards per episode:       -72.31524926686217
# Std of rewards per episode:               13.94507561932796
# Time elapsed:                             36.22 mins
# KL between old and new distribution:      [0.00998671]
# Entropy:                                  [0.03611517]
# Surrogate loss:                           [37.36678]
#
# ********** Iteration 158 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 84942
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               14.73211488448417
# Time elapsed:                             36.45 mins
# KL between old and new distribution:      [0.00999672]
# Entropy:                                  [0.03823046]
# Surrogate loss:                           [37.726425]
#
# ********** Iteration 159 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 85612
# Average sum of rewards per episode:       -73.62985074626866
# Std of rewards per episode:               24.21317647280291
# Time elapsed:                             36.68 mins
# KL between old and new distribution:      [0.00998368]
# Entropy:                                  [0.03922836]
# Surrogate loss:                           [40.6509]
#
# ********** Iteration 160 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 86284
# Average sum of rewards per episode:       -73.4077380952381
# Std of rewards per episode:               21.253510906110733
# Time elapsed:                             36.90 mins
# KL between old and new distribution:      [0.00998491]
# Entropy:                                  [0.04480555]
# Surrogate loss:                           [39.622112]
#
# ********** Iteration 161 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 86963
# Average sum of rewards per episode:       -72.64064801178203
# Std of rewards per episode:               21.271175643971667
# Time elapsed:                             37.13 mins
# KL between old and new distribution:      [0.00997678]
# Entropy:                                  [0.04327655]
# Surrogate loss:                           [39.27965]
#
# ********** Iteration 162 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 87629
# Average sum of rewards per episode:       -74.07807807807808
# Std of rewards per episode:               24.231117534420008
# Time elapsed:                             37.35 mins
# KL between old and new distribution:      [0.0099781]
# Entropy:                                  [0.04066468]
# Surrogate loss:                           [40.86877]
#
# ********** Iteration 163 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 88307
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               13.80008292060804
# Time elapsed:                             37.58 mins
# KL between old and new distribution:      [0.00997825]
# Entropy:                                  [0.03902745]
# Surrogate loss:                           [37.580574]
#
# ********** Iteration 164 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 88986
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               13.73312851320316
# Time elapsed:                             37.81 mins
# KL between old and new distribution:      [0.00996393]
# Entropy:                                  [0.04052639]
# Surrogate loss:                           [37.49181]
#
# ********** Iteration 165 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 89638
# Average sum of rewards per episode:       -75.68865030674847
# Std of rewards per episode:               18.329122792706343
# Time elapsed:                             38.03 mins
# KL between old and new distribution:      [0.00997181]
# Entropy:                                  [0.03954525]
# Surrogate loss:                           [39.87963]
#
# ********** Iteration 166 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 90319
# Average sum of rewards per episode:       -72.42290748898678
# Std of rewards per episode:               13.587061017103158
# Time elapsed:                             38.26 mins
# KL between old and new distribution:      [0.00960587]
# Entropy:                                  [0.03651509]
# Surrogate loss:                           [37.416016]
#
# ********** Iteration 167 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 90996
# Average sum of rewards per episode:       -72.85672082717873
# Std of rewards per episode:               13.808625626189185
# Time elapsed:                             38.49 mins
# KL between old and new distribution:      [0.00997399]
# Entropy:                                  [0.03532223]
# Surrogate loss:                           [37.646774]
#
# ********** Iteration 168 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 91668
# Average sum of rewards per episode:       -73.4077380952381
# Std of rewards per episode:               20.536562913797386
# Time elapsed:                             38.71 mins
# KL between old and new distribution:      [0.00999608]
# Entropy:                                  [0.03626995]
# Surrogate loss:                           [39.35875]
#
# ********** Iteration 169 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 92351
# Average sum of rewards per episode:       -72.20790629575403
# Std of rewards per episode:               17.293287711201017
# Time elapsed:                             38.94 mins
# KL between old and new distribution:      [0.00997984]
# Entropy:                                  [0.03430636]
# Surrogate loss:                           [37.987614]
#
# ********** Iteration 170 ************
# Rollout
# Made rollout
# torch.Size([1])
# Total number of episodes:                 93027
# Average sum of rewards per episode:       -72.96597633136095
# Std of rewards per episode:               11.976568436008638
# Time elapsed:                             39.17 mins
# KL between old and new distribution:      [0.00999928]
# Entropy:                                  [0.03797733]
# Surrogate loss:                           [37.364754]
#
# ********** Iteration 171 ************
# Rollout

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.org/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the mcts seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/yet_another_week/seminar_MCTS.ipynb).
#
# You can read more about in the [TRPO article](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cummulative rewards similar to `get_cummulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gym.openai.com/envs#mujoco)
# * [Box2d robot](https://gym.openai.com/envs/BipedalWalker-v2)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use fully factorized gaussian (basically a vector of gaussians).
#
# __bonus task__: compare performance of continuous action space method to action space discretization
